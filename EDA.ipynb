# %%
UDACITY ML ND CAPSTONE PROJECT:
Prostate cANcer graDe Assessment (PANDA) Kaggle Challenge

# %%
Student: Edwin J. Meyers

# %% [markdown]
# STEP 1: EXPLORATORY DATA ANALYSIS
#
# The objective in this step is to understand what type of data we are working with and hopefully discover patterns within. We will seek to understand the following aspects of the data:
#
# - Distribution of Gleason Scores
# - Distribution of Gleason Scores by source
# - Examine biopsy images and masks (hopefully have better understanding of drivers behind diagnoses and insight on how to prepare code)
# - Study color variances within biopsies (hopefully find a way to substract background) and plot variances against label Gleason/ISUP score.

# %%
# Import needed packages and tools
import skimage.io
import os
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

from PIL import Image
import s3fs
import boto3

# %%
fs = s3fs.S3FileSystem()
base_dir = "s3://test-bucket-pandas/"
img_files = "train_images"
mask_files = "train_label_masks"
fs.ls(os.path.join(base_dir,img_files))[0]
# Out:
# 'test-bucket-pandas/train_images/'

# %%
import boto3
import pandas as pd
from sagemaker import get_execution_role

role = get_execution_role()
bucket='test-bucket-pandas'
data_key = 'train.csv'
data_location = 's3://{}/{}'.format(bucket, data_key)

pd.read_csv(data_location)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/io/s3.py in get_file_and_filesystem(filepath_or_buffer, mode)
#      28     try:
# ---> 29         file = fs.open(_strip_schema(filepath_or_buffer), mode)
#      30     except (FileNotFoundError, NoCredentialsError):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/fsspec/spec.py in open(self, path, mode, block_size, cache_options, **kwargs)
#     773                 cache_options=cache_options,
# --> 774                 **kwargs
#     775             )
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/s3fs/core.py in _open(self, path, mode, block_size, acl, version_id, fill_cache, cache_type, autocommit, requester_pays, **kwargs)
#     314                       s3_additional_kwargs=kw, cache_type=cache_type,
# ...

# %%
with fs.open(f's3://test-bucket-pandas/train_images/0005f7aaab2800f6170c399693a96917.tiff') as f:display(Image.open(f))
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/s3fs/core.py in _fetch_range(client, bucket, key, version_id, start, end, max_attempts, req_kw)
#    1196                                      Range='bytes=%i-%i' % (start, end - 1),
# -> 1197                                      **kwargs)
#    1198             return resp['Body'].read()
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     315             # The "self" in this scope is referring to the BaseClient.
# --> 316             return self._make_api_call(operation_name, kwargs)
#     317
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     634             error_class = self.exceptions.from_code(error_code)
# ...
